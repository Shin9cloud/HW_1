# %%
import pandas as pd

data = pd.read_csv('sample_submission.csv')

data
# Out:
#          id  target
# 0         0       0
# 1         2       0
# 2         3       0
# 3         9       0
# 4        11       0
# ...     ...     ...
# 3258  10861       0
# 3259  10865       0
# 3260  10868       0
# 3261  10874       0
# 3262  10875       0
#
# [3263 rows x 2 columns]

# %%
import pymysql


# Connect to the database
con = pymysql.connect(host='localhost',
                         user='root',
                         password='1234',
                         db='busan')

cursor=con.cursor()
# Create a new record
sql = "INSERT INTO `submission` (`ids`, `target`) VALUES (%s, %s)"
cursor.execute(sql, (100000,'0'))
# connection is not autocommit by default. So we must commit to save our changes.
con.commit()
# Execute query
sql = "SELECT * FROM `submission`"
cursor.execute(sql)
# Fetch all the records
result = cursor.fetchall()
for i in result:
    print(i)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# c:\users\next\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# c:\users\next\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-5-07e455fe1568> in <module>
#       3
#       4 # Connect to the database
# ----> 5 con = pymysql.connect(host='localhost',
#       6                          user='root',
#       7                          password='1234',
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")

# %%
# !pip install pymysql
# Out:
# Collecting pymysql
#   Using cached PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\admin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
from sqlalchemy import create_engine
import pandas as pd
# create sqlalchemy engine
engine = create_engine("mysql+pymysql://root:1234@localhost/busan"
                       .format(user="root",
                               pw="1234",
                               db="busan"))
data = pd.read_csv('sample_submission.csv')

data.to_sql('submission', con=engine , if_exists = 'append', chunksize=10000)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1685                 if not evt_handled:
# -> 1686                     self.dialect.do_executemany(
#    1687                         cursor, statement, parameters, context
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (1054, "Unknown column 'index' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-17-72bdb8883f52> in <module>
#       8 data = pd.read_csv('sample_submission.csv')
#       9
# ---> 10 data.to_sql('submission', con=engine , if_exists = 'append', chunksize=10000)
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\core\generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2777         from pandas.io import sql
#    2778
# -> 2779         sql.to_sql(
#    2780             self,
#    2781             name,
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     599         )
#     600
# --> 601     pandas_sql.to_sql(
#     602         frame,
#     603         name,
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1417                 raise ValueError("inf cannot be used with MySQL") from err
#    1418             else:
# -> 1419                 raise err
#    1420
#    1421         if not name.isdigit() and not name.islower():
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1409
#    1410         try:
# -> 1411             table.insert(chunksize, method=method)
#    1412         except exc.SQLAlchemyError as err:
#    1413             # GH34431
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in insert(self, chunksize, method)
#     843
#     844                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 845                 exec_insert(conn, keys, chunk_iter)
#     846
#     847     def _query_iterator(
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pandas\io\sql.py in _execute_insert(self, conn, keys, data_iter)
#     760         """
#     761         data = [dict(zip(keys, row)) for row in data_iter]
# --> 762         conn.execute(self.table.insert(), data)
#     763
#     764     def _execute_insert_multi(self, conn, keys, data_iter):
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in execute(self, statement, *multiparams, **params)
#    1199             )
#    1200         else:
# -> 1201             return meth(self, multiparams, params, _EMPTY_EXECUTION_OPTS)
#    1202
#    1203     def _execute_function(self, func, multiparams, params, execution_options):
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\sql\elements.py in _execute_on_connection(self, connection, multiparams, params, execution_options, _force)
#     311     ):
#     312         if _force or self.supports_execution:
# --> 313             return connection._execute_clauseelement(
#     314                 self, multiparams, params, execution_options
#     315             )
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_clauseelement(self, elem, multiparams, params, execution_options)
#    1388             linting=self.dialect.compiler_linting | compiler.WARN_LINTING,
#    1389         )
# -> 1390         ret = self._execute_context(
#    1391             dialect,
#    1392             dialect.execution_ctx_cls._init_compiled,
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1747
#    1748         except BaseException as e:
# -> 1749             self._handle_dbapi_exception(
#    1750                 e, statement, parameters, cursor, context
#    1751             )
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1928                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    1929             elif should_wrap:
# -> 1930                 util.raise_(
#    1931                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    1932                 )
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1684                             break
#    1685                 if not evt_handled:
# -> 1686                     self.dialect.do_executemany(
#    1687                         cursor, statement, parameters, context
#    1688                     )
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\dialects\mysql\mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     146
#     147     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 148         rowcount = cursor.executemany(statement, parameters)
#     149         if context is not None:
#     150             context._rowcount = rowcount
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in executemany(self, query, args)
#     171             q_postfix = m.group(3) or ""
#     172             assert q_values[0] == "(" and q_values[-1] == ")"
# --> 173             return self._do_execute_many(
#     174                 q_prefix,
#     175                 q_values,
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     209                 sql += b","
#     210             sql += v
# --> 211         rows += self.execute(sql + postfix)
#     212         self.rowcount = rows
#     213         return rows
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# c:\users\admin\appdata\local\programs\python\python38\lib\site-packages\pymysql\err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1054, "Unknown column 'index' in 'field list'")
# [SQL: INSERT INTO submission (`index`, id, target) VALUES (%(index)s, %(id)s, %(target)s)]
# [parameters: ({'index': 0, 'id': 0, 'target': 0}, {'index': 1, 'id': 2, 'target': 0}, {'index': 2, 'id': 3, 'target': 0}, {'index': 3, 'id': 9, 'target': 0}, {'index': 4, 'id': 11, 'target': 0}, {'index': 5, 'id': 12, 'target': 0}, {'index': 6, 'id': 21, 'target': 0}, {'index': 7, 'id': 22, 'target': 0}  ... displaying 10 of 3263 total bound parameter sets ...  {'index': 3261, 'id': 10874, 'target': 0}, {'index': 3262, 'id': 10875, 'target': 0})]
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
# !pip install sqlalchemy
# Out:
# Collecting sqlalchemy
#   Downloading SQLAlchemy-1.4.11-cp38-cp38-win_amd64.whl (1.5 MB)
# Collecting greenlet!=0.4.17; python_version >= "3"
#   Downloading greenlet-1.0.0-cp38-cp38-win_amd64.whl (95 kB)
# Installing collected packages: greenlet, sqlalchemy
# Successfully installed greenlet-1.0.0 sqlalchemy-1.4.11
# WARNING: You are using pip version 20.2.3; however, version 21.0.1 is available.
# You should consider upgrading via the 'c:\users\admin\appdata\local\programs\python\python38\python.exe -m pip install --upgrade pip' command.

# %%
# Create dataframe
import pandas as pd
data=pd.DataFrame({
    'book_id':[12345,12346,12347],
    'title':['Python Programming','Learn MySQL','Data Science Cookbook'],
    'price':[29,23,27]
})

# %%
data
# Out:
#    book_id                  title  price
# 0    12345     Python Programming     29
# 1    12346            Learn MySQL     23
# 2    12347  Data Science Cookbook     27

# %%
from sqlalchemy import create_engine
pymysql.install_as_MySQLdb()
import MySQLdb
# create sqlalchemy engine
engine = create_engine("mysql+mysqldb://root:"+"1234"+"@localhost/busan", encoding='utf-8')
engine.connect()

data.to_sql(name= 'test', con=engine , if_exists = 'append')
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     612                         try:
# --> 613                             sock = socket.create_connection(
#     614                                 (self.host, self.port), self.connect_timeout, **kwargs
#
# c:\users\next\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     807         try:
# --> 808             raise err
#     809         finally:
#
# c:\users\next\appdata\local\programs\python\python38\lib\socket.py in create_connection(address, timeout, source_address)
#     795                 sock.bind(source_address)
# --> 796             sock.connect(sa)
#     797             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3141         try:
# -> 3142             return fn()
#    3143         except dialect.dbapi.Error as e:
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     760         if not fairy:
# --> 761             fairy = _ConnectionRecord.checkout(pool)
#     762
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect()
#     363         self.finalize_callback = deque()
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     352         else:
# --> 353             self.connect()
#     354
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#
# OperationalError: (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-9-6f3ca5af8859> in <module>
#       4 # create sqlalchemy engine
#       5 engine = create_engine("mysql+mysqldb://root:"+"1234"+"@localhost/busan", encoding='utf-8')
# ----> 6 engine.connect()
#       7
#       8 data.to_sql(name= 'test', con=engine , if_exists = 'append')
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in connect(self, close_with_result)
#    3094         """
#    3095
# -> 3096         return self._connection_cls(self, close_with_result=close_with_result)
#    3097
#    3098     @util.deprecated(
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      90                 connection
#      91                 if connection is not None
# ---> 92                 else engine.raw_connection()
#      93             )
#      94
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in raw_connection(self, _connection)
#    3173
#    3174         """
# -> 3175         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3176
#    3177
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3143         except dialect.dbapi.Error as e:
#    3144             if connection is None:
# -> 3145                 Connection._handle_dbapi_exception_noconnection(
#    3146                     e, dialect, self
#    3147                 )
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2002             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2003         elif should_wrap:
# -> 2004             util.raise_(
#    2005                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2006             )
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\base.py in _wrap_pool_connect(self, fn, connection)
#    3140         dialect = self.dialect
#    3141         try:
# -> 3142             return fn()
#    3143         except dialect.dbapi.Error as e:
#    3144             if connection is None:
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in _checkout(cls, pool, threadconns, fairy)
#     759     def _checkout(cls, pool, threadconns=None, fairy=None):
#     760         if not fairy:
# --> 761             fairy = _ConnectionRecord.checkout(pool)
#     762
#     763             fairy._pool = pool
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect()
#     363         self.finalize_callback = deque()
#     364
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\util\compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\pool\base.py in __connect(self)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\sqlalchemy\engine\default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in __init__(self, user, password, host, database, unix_socket, port, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, read_default_group, autocommit, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key, ssl, ssl_ca, ssl_cert, ssl_disabled, ssl_key, ssl_verify_cert, ssl_verify_identity, compress, named_pipe, passwd, db)
#     351             self._sock = None
#     352         else:
# --> 353             self.connect()
#     354
#     355     def __enter__(self):
#
# c:\users\next\appdata\local\programs\python\python38\lib\site-packages\pymysql\connections.py in connect(self, sock)
#     662                 if DEBUG:
#     663                     print(exc.traceback)
# --> 664                 raise exc
#     665
#     666             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'localhost' ([WinError 10061] 대상 컴퓨터에서 연결을 거부했으므로 연결하지 못했습니다)")
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %%
data = pd.read_csv('austin_weather.csv')
engine = create_engine("mysql+mysqldb://root:"+"1234"+"@localhost/busan", encoding='utf-8')
engine.connect()
data.to_sql(name= 'austin_weather', con=engine , if_exists = 'append')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-6df8e629e625> in <module>
#       1 data = pd.read_csv('austin_weather.csv')
# ----> 2 engine = create_engine("mysql+mysqldb://root:"+"1234"+"@localhost/busan", encoding='utf-8')
#       3 engine.connect()
#       4 data.to_sql(name= 'austin_weather', con=engine , if_exists = 'append')
#
# NameError: name 'create_engine' is not defined
